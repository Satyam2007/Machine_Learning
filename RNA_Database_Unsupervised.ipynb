# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("RNA_Database.csv")
data.head()
# Out:
#    Number of Motifs Clashes  Geometry E-density
# 0                 5       0      0.00         0
# 1                10    3.22      1.85       3.7
# 2                 1       0     19.15         0
# 3               639       0     19.15         0
# 4                 2    2.88      8.57         0

# %%
data.dtypes
# Out:
# Number of Motifs      int64
# Clashes              object
# Geometry            float64
# E-density            object
# dtype: object

# %%
#Checking for NaN
data.isnull().sum()
# Out:
# Number of Motifs    0
# Clashes             1
# Geometry            1
# E-density           3
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Number of Motifs    0
# Clashes             0
# Geometry            0
# E-density           0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Number of Motifs', 'Clashes', 'Geometry', 'E-density'], dtype='object')

# %%
data.shape
# Out:
# (4180, 4)

# %%
plt.figure(figsize=(18,10))
plt.scatter(data['Clashes'],data['Geometry'])
plt.show()
