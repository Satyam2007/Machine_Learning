# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF02695 - Nitrogen regulated small RNA
df1 = pd.read_csv("RF02695.csv")
df1.head()
# Out:
#     x    y         z
# 0  93   95  1.304102
# 1  67  163  0.607753
# 2  47   67  0.607753
# 3  47  163  0.607753
# 4   6   67  0.607753

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
