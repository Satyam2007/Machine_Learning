# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF00010 - Bacterial RNase P class A
df1 = pd.read_csv("RF00010.csv")
df1.head()
# Out:
#      x    y         z
# 0  838  857  1.764249
# 1   33  147  1.628721
# 2  680  771  1.619797
# 3  677  775  1.613325
# 4    1  992  1.597663

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
