# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF00011 - Group II catalytic intron
df1 = pd.read_csv("RF00029.csv")
df1.head()
# Out:
#     x    y         z
# 0  10   34  1.808090
# 1  13   29  1.794599
# 2  71  178  1.757618
# 3  74  174  1.623816
# 4  16   26  1.412903

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
