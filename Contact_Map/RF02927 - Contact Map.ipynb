# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF02927 - Actino-ugpB RNA
df1 = pd.read_csv("RF02927.csv")
df1.head()
# Out:
#     x   y         z
# 0  19  81  1.045827
# 1  19  63  1.029966
# 2  63  81  0.824077
# 3  57  67  0.760914
# 4  56  59  0.750927

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
