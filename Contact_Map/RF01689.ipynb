# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF01689 - AdoCbl variant RNA
df1 = pd.read_csv("RF01689.csv")
df1.head()
# Out:
#     x    y         z
# 0   4  114  1.614210
# 1  62  101  1.203987
# 2   3  115  1.167853
# 3  51   58  1.009605
# 4   2  116  0.964680

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
