# %%
#importing the packages 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing the csv file containing the contacts of the i,j pairs using pandas
#Rfam - RF00 - ZMP/ZTP riboswitch
df1 = pd.read_csv("RF01750.csv")
df1.head()
# Out:
#     x    y         z
# 0   9  216  1.129142
# 1   8  217  0.983880
# 2  11  214  0.912471
# 3  18  306  0.896515
# 4  10  215  0.861853

# %%
df1_heatmap = pd.pivot_table(df1, values='z', index=['y'], columns='x')
plt.figure(figsize=(12,10))
sns.heatmap(df1_heatmap, vmin=-0.2, vmax=0.2)
plt.show()
